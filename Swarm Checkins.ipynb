# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import foursquare
import json
import csv
from datetime import timedelta 
import googlemaps #https://github.com/googlemaps/google-maps-services-python
gmaps = googlemaps.Client(key='AIzaSyBybyv5lZzLrECqgZnOV3ZBN9aX4pogPMQ')

# %%
# Authentication
# Construct the client object
CLIENT_ID = 'VYWRXMFHL2YE1VLF1XORHPSW2AGEPCQ5C31VUIRSICKHMZ4D'
CLIENT_SECRET = 'GE02IESIHONRW3OVQVRBDVJ1QRFCKRGAIDK3UYGUQF1H530I'
AUTHORIZATION_BASE_URL = 'https://foursquare.com/oauth2/authenticate'
TOKEN_URL = 'https://foursquare.com/oauth2/access_token'

client = foursquare.Foursquare(client_id=CLIENT_ID, client_secret=CLIENT_SECRET, redirect_uri='https://liwilli.am/oauth/authorize')

# Build the authorization url for your app
auth_uri = client.oauth.auth_url()
print(auth_uri)
# Out:
# https://foursquare.com/oauth2/authenticate?client_id=VYWRXMFHL2YE1VLF1XORHPSW2AGEPCQ5C31VUIRSICKHMZ4D&response_type=code&redirect_uri=https%3A%2F%2Fliwilli.am%2Foauth%2Fauthorize

# %%
# Update token from authorization url here
token = '1RDEC24TUU1RO3451R2JEGMCVB3OHTCST4A24GRKPSXFYOGL'
access_token = client.oauth.get_token(token)

# Apply the returned access token to the client
client.set_access_token(access_token)

# User most recent data and profile information
user = client.users()

# %%
# Grab all checkins since account creation
all_checkins = client.users.checkins()

# %%
# Grab all checkins since account creation
x = client.users.all_checkins()

# Convert generator object to list
lst = list(x)
# Out:
# ---------------------------------------------------------------------------
# NotAuthorized                             Traceback (most recent call last)
# <ipython-input-185-50d25ce0e663> in <module>
#       2 x = client.users.all_checkins()
#       3 # Convert generator object to list
# ----> 4 lst = list(x)
#
# ~\Anaconda3\lib\site-packages\foursquare\__init__.py in all_checkins(self, USER_ID)
#     383             while True:
#     384                 checkins = self.checkins(
# --> 385                     USER_ID=USER_ID, params={"limit": 250, "offset": offset}
#     386                 )
#     387                 # Yield out each checkin
#
# ~\Anaconda3\lib\site-packages\foursquare\__init__.py in checkins(self, USER_ID, params, multi)
#     375             """https://developer.foursquare.com/docs/users/checkins"""
#     376             return self.GET(
# --> 377                 "{USER_ID}/checkins".format(USER_ID=USER_ID), params, multi=multi
#     378             )
#     379
#
# ~\Anaconda3\lib\site-packages\foursquare\__init__.py in GET(self, path, *args, **kwargs)
#     345         def GET(self, path=None, *args, **kwargs):
#     346             """Use the requester to get the data"""
# --> 347             return self.requester.GET(self._expanded_path(path), *args, **kwargs)
#     348
#     349         def POST(self, path=None, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\foursquare\__init__.py in GET(self, path, params, **kwargs)
#     278             params = self._enrich_params(params)
#     279             url = "{API_ENDPOINT}{path}".format(API_ENDPOINT=API_ENDPOINT, path=path)
# --> 280             result = _get(url, headers=headers, params=params, timeout=self.get_timeout)
#     281             self.rate_limit = result["headers"]["X-RateLimit-Limit"]
#     282             self.rate_remaining = result["headers"]["X-RateLimit-Remaining"]
#
# ~\Anaconda3\lib\site-packages\foursquare\__init__.py in _get(url, headers, params, timeout)
#     909                     timeout=timeout,
#     910                 )
# --> 911                 return _process_response(response)
#     912             except requests.exceptions.RequestException as e:
#     913                 _log_and_raise_exception("Error connecting with foursquare API", e)
#
# ~\Anaconda3\lib\site-packages\foursquare\__init__.py in _process_response(response)
#     955     if response.status_code == 200:
#     956         return {"headers": response.headers, "data": data}
# --> 957     return _raise_error_from_response(data)
#     958
#     959
#
# ~\Anaconda3\lib\site-packages\foursquare\__init__.py in _raise_error_from_response(data)
#     969         exc = error_types.get(meta.get("errorType"))
#     970         if exc:
# --> 971             raise exc(meta.get("errorDetail"))
#     972         else:
#     973             _log_and_raise_exception("Unknown error. meta", meta)
#
# NotAuthorized: A user is required to call this endpoint.

# %%
# Parse each check-in for specific fields
checkins = []
for checkin in lst:
    # Key:item pairs don't consistently appear for each checkin, need error exception
    try:
        created_at = checkin['createdAt']
    except:
        created_at = ''
    try:
        timezone_offset = checkin['timeZoneOffset']
    except:
        timezone_offset = ''
    try:
        venue = checkin['venue']['name']
    except:
        venue = ''
    try:
        venue_lat = checkin['venue']['location']['lat']
    except:
        venue_lat = ''
    try: 
        venue_lon = checkin['venue']['location']['lng']
    except:
        venue_lon
    try: 
        venue_postalcode = checkin['venue']['location']['postalCode']
    except:
        venue_postalcode = ''
    try: 
        venue_city = checkin['venue']['location']['city']
    except:
        venue_city = ''
    try: 
        venue_state = checkin['venue']['location']['state']
    except:
        venue_state = ''
    try: 
        venue_country = checkin['venue']['location']['country']
    except:
        venue_country = ''
    try: 
        venue_category = checkin['venue']['categories'][0]['name']
    except:
        venue_category = ''
        
    complete_data = [created_at, timezone_offset, venue, venue_lat, venue_lon, venue_postalcode, venue_city, venue_state, venue_country, venue_category]
    
    # Aggregate to single list
    checkins.append(complete_data)

# %%
# Out:
# [[1582929686,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1582926530,
#   'Chong Qing Xiao Mian',
#   37.7964178,
#   -122.4053695,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Szechuan Restaurant'],
#  [1582854380,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1582761676,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1582686852,
#   'Gai',
#   37.764384410717135,
#   -122.43007008552252,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Asian Restaurant'],
#  [1582685450,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1582505698,
#   'MUJI 無印良品',
#   37.77082581358439,
#   -122.40817709897941,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Miscellaneous Shop'],
#  [1582503035,
#   'Ocean Beach',
#   37.76629738605173,
#   -122.51062951266728,
#   '94121',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Beach'],
#  [1582494506,
#   'Teazo',
#   37.74309,
#   -122.477582,
#   '94116',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Café'],
#  [1582325686,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1582244310,
#   'SimplexiTea',
#   37.77596,
#   -122.417007,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1582236700,
#   'Super Duper Burgers',
#   37.784815548410776,
#   -122.40353657596643,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1582228699,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1582054906,
#   'Postmates HQ',
#   37.78478493967883,
#   -122.39995531921097,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Tech Startup'],
#  [1581978423,
#   '4505 Burgers & BBQ',
#   37.77612534143469,
#   -122.43814234566274,
#   '94117',
#   'San Francisco',
#   'CA',
#   'United States',
#   'BBQ Joint'],
#  [1581813350,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1581749545,
#   'Warakubune Sushi Restaurant',
#   37.766000794720576,
#   -122.42882348490592,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Sushi Restaurant'],
#  [1581642234,
#   'Rooster & Rice',
#   37.789231,
#   -122.404027,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Thai Restaurant'],
#  [1581632697,
#   'Starbucks',
#   37.78843568350366,
#   -122.40353383066646,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1581483068,
#   'Pancho Villa Taqueria',
#   37.76489031730813,
#   -122.42108881473541,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Mexican Restaurant'],
#  [1581382039,
#   'Sunrise Irving Market',
#   37.763255,
#   -122.478796,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1581375052,
#   'Wonder Tea',
#   37.763423276825144,
#   -122.48242721974742,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1581373033,
#   'Salon de Hong Kong',
#   37.76353109405784,
#   -122.4805580166012,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Salon / Barbershop'],
#  [1581298684,
#   'Shake Shack',
#   37.797899,
#   -122.435469,
#   '94123',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1581205404,
#   'insomnia cookies',
#   37.791595,
#   -122.404102,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Food & Drink Shop'],
#  [1581204099,
#   'Dong Hing Supermarket',
#   37.796954,
#   -122.408267,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1581203469,
#   'Tancca',
#   37.79752857153747,
#   -122.40996134947294,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1581200862,
#   'Sun Kau Shing Co., Inc.',
#   37.798448,
#   -122.408452,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1581194205,
#   'Super Duper Burgers',
#   37.7872473,
#   -122.3999972,
#   '94105',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1581184663,
#   'San Francisco Museum of Modern Art',
#   37.78589423994824,
#   -122.40089653026742,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Art Museum'],
#  [1580874897,
#   'OH Dessert Cafe',
#   37.763207,
#   -122.478481,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Dessert Shop'],
#  [1580869716,
#   "Phở Huỹnh Hiệp 2 - Kevin & Chris's Noodle House",
#   37.76342979551841,
#   -122.47776885111764,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1580866439,
#   'Wonder Tea',
#   37.763423276825144,
#   -122.48242721974742,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1580865899,
#   'S & B Supermarket',
#   37.763316222035364,
#   -122.48153230113245,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1580864912,
#   'Pineapple King Bakery',
#   37.763550977787865,
#   -122.47844673356455,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1580860577,
#   'Teapenter',
#   37.763760152595815,
#   -122.47433424006886,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1580855098,
#   'Walgreens',
#   37.776010810617606,
#   -122.41899132728577,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Pharmacy'],
#  [1580854568,
#   'Walgreens',
#   37.7761329,
#   -122.4226416,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Pharmacy'],
#  [1580768699,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1580613392,
#   'Whole Foods Salad Bar',
#   37.768463,
#   -122.42709,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Salad Place'],
#  [1580610884,
#   'Super Duper Burgers',
#   37.76402414195907,
#   -122.43370324373245,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1580605515,
#   'Twin Peaks Summit',
#   37.75457824954849,
#   -122.44688093662262,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Mountain'],
#  [1580253561,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1580164530,
#   'Wonder Tea',
#   37.763423276825144,
#   -122.48242721974742,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1580162880,
#   'Sunset Super',
#   37.763084747826845,
#   -122.48409779257189,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Supermarket'],
#  [1580156787,
#   'Le Trio',
#   37.761029026617464,
#   -122.48973056674002,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1580089207,
#   'iPot Plus',
#   37.599532,
#   -122.388729,
#   '94030',
#   'Millbrae',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1580081582,
#   'Tiger Tea & Juice',
#   37.593943086763616,
#   -122.38425520316258,
#   '94010',
#   'Burlingame',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1579902356,
#   'Urban Ritual',
#   37.77559476900744,
#   -122.42586342920178,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1579898205,
#   'Popeyes Louisiana Kitchen',
#   37.774928524274586,
#   -122.4379285703581,
#   '94117',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fried Chicken Joint'],
#  [1579897363,
#   'Gamescape',
#   37.772692429474894,
#   -122.43746740774097,
#   '94117',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Toy / Game Store'],
#  [1579741244,
#   'Chong Qing Xiao Mian',
#   37.7964178,
#   -122.4053695,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Szechuan Restaurant'],
#  [1579729410,
#   'Blue Bottle Coffee',
#   37.789744,
#   -122.403652,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1579469235,
#   'Cool Tea Bar',
#   37.79427316547421,
#   -122.40680729100923,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1579468991,
#   'Duk Hing',
#   37.796464,
#   -122.408342,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Butcher'],
#  [1579466611,
#   'Zhen Mei Hair Salon',
#   37.794412123814105,
#   -122.40556072517326,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Salon / Barbershop'],
#  [1579329545,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1579320156,
#   'Hollywood Burbank Airport (BUR)',
#   34.19635394679802,
#   -118.35297703742982,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Airport'],
#  [1579299535,
#   "Trader Joe's",
#   34.127804239100726,
#   -118.08957143316364,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1579298399,
#   'Good Fortune Supermarket',
#   34.10195254675744,
#   -118.09168495611375,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Supermarket'],
#  [1579294020,
#   'Delicious Food Corner',
#   34.102576817940225,
#   -118.10805637218377,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1579213334,
#   'Half & Half Tea Express 伴伴堂',
#   34.127722409740734,
#   -118.09092901426104,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Tea Room'],
#  [1579212494,
#   'CVS pharmacy',
#   34.127841104362915,
#   -118.08962983799435,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Pharmacy'],
#  [1579209508,
#   'Golden Deli Vietnamese Restaurant',
#   34.102792400002144,
#   -118.1117266923932,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1579143090,
#   'Half & Half Good Old Time',
#   34.102165979423326,
#   -118.1099375230333,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Café'],
#  [1579131814,
#   'Premier Care Dental Group',
#   34.14046389,
#   -118.13188703,
#   '91101',
#   'Pasadena',
#   'CA',
#   'United States',
#   "Dentist's Office"],
#  [1579037756,
#   '99 Ranch Market',
#   34.123975284234994,
#   -118.05924187576379,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Supermarket'],
#  [1579037356,
#   'CVS pharmacy',
#   34.12367485059952,
#   -118.0564145157803,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Pharmacy'],
#  [1579036631,
#   'Tong Tak House',
#   34.124739,
#   -118.055588,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1578950825,
#   'Sterling Bank & Trust',
#   34.126534,
#   -118.05390600000001,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Bank'],
#  [1578947283,
#   'Din Tai Fung',
#   34.13509295122126,
#   -118.05167794973755,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Dumpling Restaurant'],
#  [1578856382,
#   'Grand Harbor Restaurant',
#   34.104048990416715,
#   -118.07545060774558,
#   '91780',
#   'Temple City',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1578711295,
#   'Walgreens',
#   34.14037659831915,
#   -118.13187612226102,
#   '91101',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Pharmacy'],
#  [1578708940,
#   'Premier Care Dental Group',
#   34.14046389,
#   -118.13188703,
#   '91101',
#   'Pasadena',
#   'CA',
#   'United States',
#   "Dentist's Office"],
#  [1578699810,
#   "McDonald's",
#   34.19464568533633,
#   -118.34924340248108,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1578698409,
#   'Hollywood Burbank Airport (BUR)',
#   34.19635394679802,
#   -118.35297703742982,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Airport'],
#  [1578689911,
#   'Starbird',
#   37.61198211028136,
#   -122.38523744250415,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1578689207,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1578427689,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1578346974,
#   'SimplexiTea',
#   37.77596,
#   -122.417007,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1578336755,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1578261670,
#   'Tea Hut',
#   37.787924,
#   -122.440756,
#   '94115',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1578118788,
#   'Harvey Milk Terminal 1',
#   37.614639352839696,
#   -122.38488435745238,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport Terminal'],
#  [1578117582,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1578108821,
#   'Hollywood Burbank Airport (BUR)',
#   34.19635394679802,
#   -118.35297703742982,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Airport'],
#  [1578106519,
#   'Uncle Tetsu Japanese Cheesecake',
#   34.13495422176463,
#   -118.05207008484189,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Dessert Shop'],
#  [1578104077,
#   'Dongpo Restaurant',
#   34.133701,
#   -118.053163,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Szechuan Restaurant'],
#  [1578004215,
#   'The Huntington Library, Art Collections, and Botanical Gardens',
#   34.12899118986631,
#   -118.1135630607605,
#   '91108',
#   'San Marino',
#   'CA',
#   'United States',
#   'Museum'],
#  [1577929701,
#   'Monterey Palace Restaurant',
#   34.06286926861878,
#   -118.10915412380987,
#   '91755',
#   'Monterey Park',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1577831911,
#   'Good Fortune Supermarket',
#   34.10195254675744,
#   -118.09168495611375,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Supermarket'],
#  [1577827408,
#   'Grand Harbor Restaurant',
#   34.104048990416715,
#   -118.07545060774558,
#   '91780',
#   'Temple City',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1577758697,
#   'Ave 26 Taco Stand',
#   34.08025736927688,
#   -118.21771991398326,
#   '90031',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Taco Place'],
#  [1577757214,
#   'Café Dulcé',
#   34.0488687598013,
#   -118.24050832309565,
#   '90012',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1577755226,
#   'Milk + T',
#   34.04913217306648,
#   -118.24147199045751,
#   '90012',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1577737426,
#   '85°C Bakery Cafe',
#   34.129661,
#   -118.028648,
#   '91006',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1577735518,
#   "B-Man's Teriyaki & Burgers",
#   34.12759890401646,
#   -118.09110865952208,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'American Restaurant'],
#  [1577664519,
#   'H Mart',
#   34.1316019290268,
#   -118.0658844388728,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1577660881,
#   'Meet Fresh',
#   34.134177,
#   -118.052382,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Dessert Shop'],
#  [1577651996,
#   'AMC Santa Anita 16',
#   34.1353904958751,
#   -118.04887345491872,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1577648088,
#   "B-Man's Teriyaki & Burgers",
#   34.12759890401646,
#   -118.09110865952208,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'American Restaurant'],
#  [1577577776,
#   'Methodist Hospital of Southern California',
#   34.1344486,
#   -118.0416623,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Hospital'],
#  [1577566179,
#   "Trader Joe's",
#   34.127804239100726,
#   -118.08957143316364,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1577565019,
#   '99 Ranch Market',
#   34.123975284234994,
#   -118.05924187576379,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Supermarket'],
#  [1577564114,
#   'Wells Fargo',
#   34.12586388211495,
#   -118.05464297533035,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Bank'],
#  [1577482375,
#   'Sunmerry Bakery / Happy Lemon',
#   34.06862167139086,
#   -118.1337483601634,
#   '91754',
#   'Monterey Park',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1577481434,
#   'Gatten Sushi',
#   34.06762145217161,
#   -118.13422571529146,
#   '91754',
#   'Monterey Park',
#   'CA',
#   'United States',
#   'Sushi Restaurant'],
#  [1577424690,
#   'KFC',
#   33.88820765240491,
#   -117.82739083598159,
#   '92886',
#   'Yorba Linda',
#   'CA',
#   'United States',
#   'Fried Chicken Joint'],
#  [1577396546,
#   'Adobo Taco Grill',
#   33.8596530073736,
#   -118.11754173787527,
#   '90713',
#   'Lakewood',
#   'CA',
#   'United States',
#   'Taco Place'],
#  [1577232761,
#   'Hollywood Burbank Airport (BUR)',
#   34.19635394679802,
#   -118.35297703742982,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Airport'],
#  [1577226078,
#   'Oakland International Airport (OAK)',
#   37.71151617933207,
#   -122.21352054664057,
#   '94621',
#   'Oakland',
#   'CA',
#   'United States',
#   'Airport'],
#  [1577220827,
#   'Starbird',
#   37.61198211028136,
#   -122.38523744250415,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1577218599,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1577073683,
#   'Kitchen Story',
#   37.764236,
#   -122.430744,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Breakfast Spot'],
#  [1577039039,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1576902805,
#   'R&G Lounge 嶺南小館',
#   37.79407153466883,
#   -122.40472405865627,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1576894507,
#   'Target',
#   37.79104466848959,
#   -122.40083151432805,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Big Box Store'],
#  [1576613579,
#   'S&T Hong Kong Seafood',
#   37.75370241972955,
#   -122.49127836453927,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1576547750,
#   'Yummy Bakery and Cafe',
#   37.79731597161611,
#   -122.40467989841153,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1576545334,
#   'Slurp Ramen',
#   37.79406320155133,
#   -122.40493312355578,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Ramen Restaurant'],
#  [1576542567,
#   'Sennheiser',
#   37.788807,
#   -122.406575,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Music Store'],
#  [1576540453,
#   'Saks Fifth Avenue',
#   37.78860367704878,
#   -122.40810665486606,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Department Store'],
#  [1576534018,
#   'Chocolate Chair Organic Ice Cream',
#   37.785118105028,
#   -122.43093194797312,
#   '94115',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Ice Cream Shop'],
#  [1576532813,
#   'Cathedral of Saint Mary of the Assumption',
#   37.78472011778899,
#   -122.42508879670633,
#   '94109',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Church'],
#  [1576459812,
#   'Tasty Pot 味鼎 Taiwanese Cuisine',
#   37.782761161730114,
#   -122.46800944513556,
#   '94118',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Hotpot Restaurant'],
#  [1576454982,
#   'Crissy Field',
#   37.804341954682855,
#   -122.46535062789917,
#   '94129',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Park'],
#  [1576452539,
#   'Palace of Fine Arts',
#   37.80288814426483,
#   -122.44841247797011,
#   '94123',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Historic Site'],
#  [1576451172,
#   'Ferry Building Marketplace',
#   37.79553812238765,
#   -122.39347279071806,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Market'],
#  [1576446475,
#   'Salesforce Transit Center Gondola',
#   37.79014,
#   -122.3967,
#   '94105',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Cable Car'],
#  [1576443267,
#   'Super Duper Burgers',
#   37.786953,
#   -122.403992,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1576439330,
#   "San Francisco City Attorney's Office",
#   37.77927985391918,
#   -122.41889476776122,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'City Hall'],
#  [1576098779,
#   'Uniq Salon',
#   37.79414150175996,
#   -122.4076844649953,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Salon / Barbershop'],
#  [1575858608,
#   'Everlane',
#   37.76552449153237,
#   -122.42184074310325,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Clothing Store'],
#  [1575856849,
#   "McDonald's",
#   37.7521054,
#   -122.4180956,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1575854997,
#   'La Taqueria',
#   37.750949,
#   -122.418129,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burrito Place'],
#  [1575850827,
#   'Lands End',
#   37.78315503056424,
#   -122.51118555665016,
#   '94121',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Park'],
#  [1575834716,
#   'Johnny Doughnuts',
#   37.7788294004348,
#   -122.42316169019617,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Donut Shop'],
#  [1575782303,
#   "Phở Huỹnh Hiệp 2 - Kevin & Chris's Noodle House",
#   37.76342979551841,
#   -122.47776885111764,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1575766746,
#   'Safeway',
#   37.7691214,
#   -122.4283067,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1575760627,
#   'Bear Basics',
#   37.86774689892123,
#   -122.25908144027782,
#   '94704',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Accessories Store'],
#  [1575759369,
#   "Artichoke Basille's Pizza",
#   37.86813337127359,
#   -122.25684987082354,
#   '94704',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Pizza Place'],
#  [1575758385,
#   'Bancroft Clothing',
#   37.868589443824696,
#   -122.25844644606855,
#   '94704',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Clothing Store'],
#  [1575757256,
#   'Cal Student Store',
#   37.86850148557906,
#   -122.25985050201416,
#   '94720',
#   'Berkeley',
#   'CA',
#   'United States',
#   'College Bookstore'],
#  [1575749747,
#   'Cheese Board Pizza',
#   37.879873403960836,
#   -122.2692930474587,
#   '94709',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Pizza Place'],
#  [1575697936,
#   'Tunnel Top',
#   37.790278000572236,
#   -122.4072361885583,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bar'],
#  [1575693798,
#   'Bar Fluxus',
#   37.79036768606403,
#   -122.40492775866001,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Cocktail Bar'],
#  [1575688051,
#   'Pagan Idol',
#   37.790726,
#   -122.403643,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Tiki Bar'],
#  [1575686631,
#   'Flybird',
#   37.788357,
#   -122.403711,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fried Chicken Joint'],
#  [1575673716,
#   'Cool Tea Bar',
#   37.79427316547421,
#   -122.40680729100923,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1575672829,
#   'Golden Gate Bakery',
#   37.79643506491485,
#   -122.40673366663002,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1575665769,
#   'Black Sugar',
#   37.786135125067496,
#   -122.40994756960231,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1575661982,
#   'Creator',
#   37.78433099342128,
#   -122.39842371609498,
#   '94107',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1575660485,
#   'RazerStore San Francisco',
#   37.78380131359328,
#   -122.4074652889648,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Electronics Store'],
#  [1575501150,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1575343802,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1575321050,
#   'Los Angeles International Airport (LAX)',
#   33.94332434443264,
#   -118.405601978302,
#   '90045',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Airport'],
#  [1575317925,
#   'Sam Woo BBQ',
#   34.10432744116962,
#   -118.0865843822355,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1575232941,
#   "B-Man's Teriyaki & Burgers",
#   34.12759890401646,
#   -118.09110865952208,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'American Restaurant'],
#  [1575155664,
#   'Tea Maru',
#   34.102674673134494,
#   -118.11050860043211,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1575079963,
#   'Starbucks',
#   34.13598071067208,
#   -118.13240508468039,
#   '91101',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1575066928,
#   'One Zo Boba',
#   34.145452,
#   -118.150367,
#   '91105',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1574967725,
#   'Grand Harbor Restaurant',
#   34.104048990416715,
#   -118.07545060774558,
#   '91780',
#   'Temple City',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1574896276,
#   'Los Angeles International Airport (LAX)',
#   33.94332434443264,
#   -118.405601978302,
#   '90045',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Airport'],
#  [1574886331,
#   'Yankee Pier',
#   37.618131295842005,
#   -122.38711595535278,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Seafood Restaurant'],
#  [1574884229,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1574722059,
#   'Naya Dessert Cafe',
#   37.777174,
#   -122.424859,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Dessert Shop'],
#  [1574554309,
#   'Shihlin Taiwan Street Snacks 士林臺灣小吃',
#   37.727817534627626,
#   -122.47646649433597,
#   '94132',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Taiwanese Restaurant'],
#  [1574554030,
#   '85C Bakery Cafe - Stonestown',
#   37.72791847111096,
#   -122.47628171618449,
#   '94132',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1574553209,
#   'My Cup Of Tea',
#   37.73228196865914,
#   -122.47440691239956,
#   '94132',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1574463443,
#   'Tea And Others',
#   37.771351,
#   -122.437029,
#   '94117',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1574285628,
#   'SimplexiTea',
#   37.77596,
#   -122.417007,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1574282442,
#   'Phở Tan Hoa',
#   37.78532888249675,
#   -122.41289637594134,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1573943223,
#   'Costco Food Court',
#   37.89858601187579,
#   -122.32044696137314,
#   '94804',
#   'Richmond',
#   'CA',
#   'United States',
#   'Food Court'],
#  [1573938597,
#   'Costco',
#   37.89856499930334,
#   -122.32041742351264,
#   '94804',
#   'Richmond',
#   'CA',
#   'United States',
#   'Warehouse Store'],
#  [1573687855,
#   'Dough',
#   37.775747,
#   -122.418157,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Pizza Place'],
#  [1573682710,
#   'SimplexiTea',
#   37.77596,
#   -122.417007,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1573673567,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1572985893,
#   'Freshroll Vietnamese Rolls and Bowls',
#   37.791095128375794,
#   -122.40122990649495,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1572903558,
#   'Urban Ritual',
#   37.77559476900744,
#   -122.42586342920178,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1572902765,
#   'Popeyes Louisiana Kitchen',
#   37.774928524274586,
#   -122.4379285703581,
#   '94117',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fried Chicken Joint'],
#  [1572646796,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1572382647,
#   'San Francisco Bay Ferry - Alameda Main Street Terminal',
#   37.790618661599495,
#   -122.29389982714868,
#   '94501',
#   'Alameda',
#   'CA',
#   'United States',
#   'Boat or Ferry'],
#  [1572376723,
#   'East Ocean Seafood Restaurant',
#   37.77661024778986,
#   -122.27688987277787,
#   '94501',
#   'Alameda',
#   'CA',
#   'United States',
#   'Seafood Restaurant'],
#  [1572294285,
#   'Brew Cha',
#   37.76183444542872,
#   -122.42005353388947,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1571698956,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1571521641,
#   "Phở Huỹnh Hiệp 2 - Kevin & Chris's Noodle House",
#   37.76342979551841,
#   -122.47776885111764,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1571515537,
#   'Ocean Beach',
#   37.76629738605173,
#   -122.51062951266728,
#   '94121',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Beach'],
#  [1571439810,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1571428921,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1571426689,
#   'Super Duper Burgers',
#   37.784815548410776,
#   -122.40353657596643,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1571347071,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1571340561,
#   'Three Embarcadero Center',
#   37.795041961791135,
#   -122.39735911923606,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Shopping Mall'],
#  [1571340081,
#   'Good Mong Kok Bakery',
#   37.795458712845154,
#   -122.40818052928776,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1571334187,
#   'Home',
#   37.791312,
#   -122.405899,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1571271090,
#   'Jasmine Garden',
#   37.76769379927239,
#   -122.42924321500816,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1571267960,
#   'Verve Coffee Roasters',
#   37.767121,
#   -122.429152,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1571176034,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1571107458,
#   'Urban Ritual',
#   37.77559476900744,
#   -122.42586342920178,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1571007397,
#   'SimplexiTea',
#   37.77596,
#   -122.417007,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1570830065,
#   'SimplexiTea',
#   37.77596,
#   -122.417007,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1570820338,
#   'Sens Restaurant',
#   37.795182777756686,
#   -122.39516697787235,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Mediterranean Restaurant'],
#  [1570745449,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1570653596,
#   'i-Tea',
#   37.7906249241228,
#   -122.40401274308272,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1570652560,
#   'Utopia Cafe',
#   37.794697,
#   -122.40707,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1570641268,
#   'Home',
#   37.791312,
#   -122.405899,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1570559482,
#   'Rooster & Rice',
#   37.789231,
#   -122.404027,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Thai Restaurant'],
#  [1570553211,
#   'Home',
#   37.791312,
#   -122.405899,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1570493130,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1570484008,
#   'Hollywood Burbank Airport (BUR)',
#   34.19635394679802,
#   -118.35297703742982,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Airport'],
#  [1570478963,
#   'Sam Woo BBQ',
#   34.10432744116962,
#   -118.0865843822355,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1570413754,
#   'Ramen Yukinoya',
#   34.12303497028853,
#   -118.05586528447347,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Noodle House'],
#  [1570398317,
#   'The Crack Shack',
#   34.14423,
#   -118.15115,
#   '91105',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Fried Chicken Joint'],
#  [1570395114,
#   'Mt. Lowe Brewery',
#   34.14326912450857,
#   -118.02641247729441,
#   '91006',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Brewery'],
#  [1570298209,
#   "B-Man's Teriyaki & Burgers",
#   34.12759890401646,
#   -118.09110865952208,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'American Restaurant'],
#  [1570237693,
#   'Maki & Sushi Arcadia',
#   34.13986231934596,
#   -118.02387103809137,
#   '91006',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Sushi Restaurant'],
#  [1570158124,
#   "Trader Joe's",
#   34.127804239100726,
#   -118.08957143316364,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1570127773,
#   'Grand Harbor Restaurant',
#   34.104048990416715,
#   -118.07545060774558,
#   '91780',
#   'Temple City',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1570042604,
#   "Consulate General of the People's Republic of China",
#   34.0650657853072,
#   -118.2897001759952,
#   '90020',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Embassy / Consulate'],
#  [1569960212,
#   '99 Ranch Market',
#   34.123975284234994,
#   -118.05924187576379,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Supermarket'],
#  [1569959810,
#   'Full House Seafood Restaurant',
#   34.12488088781389,
#   -118.05929943656766,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1569954257,
#   'Hollywood Burbank Airport (BUR)',
#   34.19635394679802,
#   -118.35297703742982,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Airport'],
#  [1569944592,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1569865897,
#   'Home',
#   37.791312,
#   -122.405899,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1569863988,
#   'Mazarine Coffee',
#   37.78745542538577,
#   -122.40384241107367,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1569722012,
#   'Little Giant Ice Cream',
#   37.80906010977746,
#   -122.26977821542515,
#   '94612',
#   'Oakland',
#   'CA',
#   'United States',
#   'Ice Cream Shop'],
#  [1569719579,
#   'TrueBurger',
#   37.811271532286334,
#   -122.26404547691345,
#   '94612',
#   'Oakland',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1569709632,
#   'Feng Cha',
#   37.867768,
#   -122.258127,
#   '94704',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1569441349,
#   'Mendocino Farms',
#   37.79285019448193,
#   -122.40236295612837,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Restaurant'],
#  [1569184341,
#   'Uniq Salon',
#   37.79414150175996,
#   -122.4076844649953,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Salon / Barbershop'],
#  [1569182203,
#   'Yi Fang Taiwan Fruit Tea',
#   37.795038,
#   -122.407614,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1568944004,
#   'Exploratorium',
#   37.80086420601844,
#   -122.3985555768013,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Science Museum'],
#  [1568921040,
#   'Noodle Me',
#   37.79227947908223,
#   -122.3974140152664,
#   '94105',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Noodle House'],
#  [1568511539,
#   'Emeryville Marina',
#   37.840556,
#   -122.314305,
#   '94608',
#   'Emeryville',
#   'CA',
#   'United States',
#   'Harbor / Marina'],
#  [1568400802,
#   'Flybird',
#   37.788357,
#   -122.403711,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fried Chicken Joint'],
#  [1568234320,
#   'Mendocino Farms',
#   37.79285019448193,
#   -122.40236295612837,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Restaurant'],
#  [1568144696,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1567977029,
#   'My Cup Of Tea',
#   37.73228196865914,
#   -122.47440691239956,
#   '94132',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1567973977,
#   "Phở Huỹnh Hiệp 2 - Kevin & Chris's Noodle House",
#   37.76342979551841,
#   -122.47776885111764,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1567894706,
#   'Super Duper Burgers',
#   37.784815548410776,
#   -122.40353657596643,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1567886213,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1567824220,
#   'CoCo Fresh Tea & Juice',
#   37.788419505847095,
#   -122.40273755214469,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1567809310,
#   'Slurp Ramen',
#   37.79406320155133,
#   -122.40493312355578,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Ramen Restaurant'],
#  [1567624399,
#   'The Ramen Bar',
#   37.79295,
#   -122.3981,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Ramen Restaurant'],
#  [1567564182,
#   "Schroeder's",
#   37.79390595738287,
#   -122.39883885347422,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'German Restaurant'],
#  [1567538811,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1567473057,
#   'China Beach',
#   37.788089862931265,
#   -122.49118566513062,
#   '94121',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Beach'],
#  [1567472047,
#   'Eagles Point',
#   37.786713525391306,
#   -122.49481025151098,
#   '',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Scenic Lookout'],
#  [1567470679,
#   'Lands End Coastal Trail',
#   37.78418314781439,
#   -122.50902235507965,
#   '94121',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Trail'],
#  [1567464832,
#   'Purple Kow',
#   37.775778308127286,
#   -122.49776679160817,
#   '94121',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1567302312,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1567289963,
#   'Black Sugar',
#   37.786135125067496,
#   -122.40994756960231,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1567289089,
#   'Super Duper Burgers',
#   37.784815548410776,
#   -122.40353657596643,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1566934678,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1566856942,
#   'Asha Tea House',
#   37.788175,
#   -122.403615,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Tea Room'],
#  [1566839444,
#   'Specialty’s Café & Bakery',
#   37.78899121295121,
#   -122.40212403466892,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1566675293,
#   'Teapenter',
#   37.763760152595815,
#   -122.47433424006886,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1566674564,
#   "Phở Huỹnh Hiệp 2 - Kevin & Chris's Noodle House",
#   37.76342979551841,
#   -122.47776885111764,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1566607557,
#   'SimplexiTea',
#   37.77596,
#   -122.417007,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1566524362,
#   'FedEx Ship Center',
#   37.748086,
#   -122.394698,
#   '94124',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Shipping Store'],
#  [1566330194,
#   'The Boy’s Deli',
#   37.792276,
#   -122.40316,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Deli / Bodega'],
#  [1566165421,
#   'STEAP TEA BAR',
#   37.79335935707923,
#   -122.40657290440264,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1566163638,
#   'Little Swan Bakery Cafe',
#   37.79736770950945,
#   -122.4086209443147,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1566081999,
#   'SimplexiTea',
#   37.77596,
#   -122.417007,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1566080885,
#   'Super Duper Burgers',
#   37.784815548410776,
#   -122.40353657596643,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1566068686,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1566002323,
#   'Beauty Style Exchange',
#   37.794204763342826,
#   -122.4065385718265,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Salon / Barbershop'],
#  [1565899296,
#   'Onigilly',
#   37.791467040344536,
#   -122.40406312658435,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Japanese Restaurant'],
#  [1565730800,
#   'La Mar',
#   37.797398376022706,
#   -122.39510258312372,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Peruvian Restaurant'],
#  [1565561071,
#   'District Tea',
#   37.76245,
#   -122.41958,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1565559129,
#   'Koi Palace',
#   37.66612402992314,
#   -122.46671141773949,
#   '94015',
#   'Daly City',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1565485323,
#   'Yi Fang Taiwan Fruit Tea',
#   37.86876799201421,
#   -122.2587863734814,
#   '94704',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1565480001,
#   'Martin Luther King Jr. Student Union',
#   37.86899288658927,
#   -122.25947780007033,
#   '94720',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Student Center'],
#  [1565479327,
#   'Fruit T',
#   37.86837,
#   -122.259895,
#   '94704',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1565477183,
#   'Shihlin Taiwan Street Snacks',
#   37.86818027517792,
#   -122.25808230591021,
#   '94704',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Snack Place'],
#  [1564972135,
#   'Izakaya Sozai',
#   37.76375789663464,
#   -122.47406176406999,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Japanese Restaurant'],
#  [1564960087,
#   'U :Dessert Story',
#   37.76432999836782,
#   -122.430725252748,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Dessert Shop'],
#  [1564711057,
#   'SFMOMA Rooftop Sculpture Garden',
#   37.7863356901678,
#   -122.4004037044823,
#   '',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Art Museum'],
#  [1564688135,
#   'Gott’s Roadside',
#   37.795793782401226,
#   -122.39424059385291,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1564258737,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1563586873,
#   'Panda Express',
#   37.78324920096857,
#   -122.43249729307273,
#   '94115',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1562809057,
#   'Panda Express',
#   37.78400418036148,
#   -122.4074490269985,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1562613117,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1562529481,
#   'Golden Dragon',
#   34.065546260692926,
#   -118.23648107273037,
#   '90012',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1562472674,
#   "B-Man's Teriyaki & Burgers",
#   34.12759890401646,
#   -118.09110865952208,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'American Restaurant'],
#  [1562469959,
#   'Half & Half Tea Express 伴伴堂',
#   34.127722409740734,
#   -118.09092901426104,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Tea Room'],
#  [1562453594,
#   'Jones Coffee Roasters',
#   34.133712016931874,
#   -118.14913000468529,
#   '91105',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1562443626,
#   'Bopomofo Cafe',
#   34.102319834573564,
#   -118.11184564869303,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Café'],
#  [1562439559,
#   'Golden Deli Vietnamese Restaurant',
#   34.102792400002144,
#   -118.1117266923932,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1562375079,
#   'The Noodle',
#   34.12570071766437,
#   -118.0546527436334,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1562370549,
#   'Sterling Bank & Trust',
#   34.126534,
#   -118.05390600000001,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Bank'],
#  [1562359088,
#   "B-Man's Teriyaki & Burgers",
#   34.12759890401646,
#   -118.09110865952208,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'American Restaurant'],
#  [1562264711,
#   'Grand Harbor Restaurant',
#   34.104048990416715,
#   -118.07545060774558,
#   '91780',
#   'Temple City',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1562181336,
#   'Starbucks',
#   35.98772604,
#   -119.9592483,
#   '93239',
#   'Kettleman City',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1562031223,
#   'Beauty Style Exchange',
#   37.794204763342826,
#   -122.4065385718265,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Salon / Barbershop'],
#  [1561855101,
#   "Phở Huỹnh Hiệp 2 - Kevin & Chris's Noodle House",
#   37.76342979551841,
#   -122.47776885111764,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1561774353,
#   'Pakwan',
#   37.76489902919094,
#   -122.42368140944069,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Pakistani Restaurant'],
#  [1561405151,
#   'Happy Donuts',
#   37.79151196560991,
#   -122.39946859710487,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Donut Shop'],
#  [1561335768,
#   '85C Bakery Cafe - Stonestown',
#   37.72791847111096,
#   -122.47628171618449,
#   '94132',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bakery'],
#  [1561335148,
#   'UNIQLO',
#   37.72838963378139,
#   -122.47700837724764,
#   '94132',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Clothing Store'],
#  [1561329844,
#   'SimpleTea',
#   37.732064,
#   -122.473504,
#   '94132',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1561061433,
#   'Braised + Bread',
#   37.7893304378607,
#   -122.40274712864758,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Cambodian Restaurant'],
#  [1560631166,
#   'Miss SaiGon',
#   37.78090859241695,
#   -122.4087027215203,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1560630221,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1560482288,
#   "Roy's",
#   37.788341,
#   -122.399179,
#   '94105',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Hawaiian Restaurant'],
#  [1560400181,
#   'Sunset Shabu',
#   37.762871,
#   -122.46611,
#   '94122',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Shabu-Shabu Restaurant'],
#  [1560281826,
#   'Localli Meditteranean',
#   37.791942,
#   -122.399766,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Mediterranean Restaurant'],
#  [1560216306,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1560200086,
#   'Sightglass Coffee',
#   37.77700097623915,
#   -122.40851927201014,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1560194417,
#   'Miss SaiGon',
#   37.78090859241695,
#   -122.4087027215203,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1560180878,
#   'Hall of Justice',
#   37.7752584015384,
#   -122.40377633446539,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Courthouse'],
#  [1560120328,
#   'Magical Ice Cream',
#   37.795208,
#   -122.406394,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Ice Cream Shop'],
#  [1560117151,
#   'Utopia Cafe',
#   37.794697,
#   -122.40707,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1560113789,
#   'Little Swan Bakery Cafe',
#   37.79736770950945,
#   -122.4086209443147,
#   '94133',
# ...
#   '94607',
#   'Oakland',
#   'CA',
#   'United States',
#   'Wine Shop'],
#  [1518216242,
#   'Oakland Ferry Terminal',
#   37.7950845277853,
#   -122.27967304269424,
#   '94607',
#   'Oakland',
#   'CA',
#   'United States',
#   'Pier'],
#  [1518206006,
#   'Super Duper Burger',
#   37.7914365,
#   -122.4039689,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1518109228,
#   'Willis Towers Watson',
#   37.792732637967866,
#   -122.40029551028968,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Office'],
#  [1518022915,
#   'Willis Towers Watson',
#   37.792732637967866,
#   -122.40029551028968,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Office'],
#  [1517969383,
#   'Eyedare',
#   37.764917,
#   -122.423857,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Optical Shop'],
#  [1517859261,
#   'Willis Towers Watson',
#   37.792732637967866,
#   -122.40029551028968,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Office'],
#  [1517687360,
#   'SoMa StrEat Food Park',
#   37.76964417224087,
#   -122.41175489448761,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Street Food Gathering'],
#  [1517586515,
#   'Blue Bottle Coffee',
#   37.79132021905332,
#   -122.40098297595978,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Coffee Shop'],
#  [1517520314,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1517371846,
#   'Chengdu Style Restaurant',
#   37.86874107338216,
#   -122.25687410687469,
#   '94704',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1517365025,
#   'Amazon@ASUC Student Union',
#   37.86929705907425,
#   -122.25938667401753,
#   '94720',
#   'Berkeley',
#   'CA',
#   'United States',
#   'Shipping Store'],
#  [1517165258,
#   "Lowe's",
#   37.7399074,
#   -122.4062275,
#   '94124',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Hardware Store'],
#  [1517084048,
#   "Angelica's Hair Salon",
#   37.757517,
#   -122.420957,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Cosmetics Shop'],
#  [1517079979,
#   'Best Buy',
#   37.7686504,
#   -122.4129792,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Electronics Store'],
#  [1516996195,
#   'Osha Thai Restaurant & Lounge',
#   37.79495003630765,
#   -122.39534094434025,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Thai Restaurant'],
#  [1516912539,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1516656034,
#   'Onigilly',
#   37.791467040344536,
#   -122.40406312658435,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Japanese Restaurant'],
#  [1516398459,
#   'City View Restaurant',
#   37.794191,
#   -122.403918,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1516315262,
#   'i-Tea',
#   37.7906249241228,
#   -122.40401274308272,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1515975778,
#   "Trader Joe's",
#   37.78554041959348,
#   -122.40545481697127,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1515974984,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1515703994,
#   'Oasis Grill',
#   37.79448295699703,
#   -122.39671156917977,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Mediterranean Restaurant'],
#  [1515445897,
#   'Toy Soldier',
#   37.79145871851356,
#   -122.40383347056067,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'New American Restaurant'],
#  [1515389522,
#   'House of Thai',
#   37.786188482627075,
#   -122.41816498658896,
#   '94109',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Thai Restaurant'],
#  [1515386768,
#   'Smitten Ice Cream',
#   37.758342540653345,
#   -122.4212909831678,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Ice Cream Shop'],
#  [1515283040,
#   'Enough',
#   37.78856055476051,
#   -122.40355624900326,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1515273724,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1515272732,
#   'Super Duper Burgers',
#   37.784815548410776,
#   -122.40353657596643,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1515176631,
#   'Willis Towers Watson',
#   37.792732637967866,
#   -122.40029551028968,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Office'],
#  [1515096624,
#   'Willis Towers Watson',
#   37.792732637967866,
#   -122.40029551028968,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Office'],
#  [1515037161,
#   'SQwers Izakaya & Sushi BAR',
#   37.78189618301288,
#   -122.45134008269928,
#   '94118',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Sushi Restaurant'],
#  [1514943329,
#   'Willis Towers Watson',
#   37.792732637967866,
#   -122.40029551028968,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Office'],
#  [1514855959,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1514844999,
#   'Hollywood Burbank Airport (BUR)',
#   34.19635394679802,
#   -118.35297703742982,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Airport'],
#  [1514841854,
#   'ABC Seafood',
#   34.06007060356406,
#   -118.23837663293081,
#   '90012',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1514751076,
#   'Miniso',
#   34.104582,
#   -118.074978,
#   '91780',
#   'Temple City',
#   'CA',
#   'United States',
#   'Discount Store'],
#  [1514747802,
#   'Grand Harbor Restaurant',
#   34.104048990416715,
#   -118.07545060774558,
#   '91780',
#   'Temple City',
#   'CA',
#   'United States',
#   'Cantonese Restaurant'],
#  [1514581238,
#   "Trader Joe's",
#   34.127804239100726,
#   -118.08957143316364,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1514580645,
#   'CVS pharmacy',
#   34.127841104362915,
#   -118.08962983799435,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'Pharmacy'],
#  [1514237190,
#   'H Mart',
#   34.1316019290268,
#   -118.0658844388728,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1514158576,
#   'Good Fortune Supermarket',
#   34.10195254675744,
#   -118.09168495611375,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Supermarket'],
#  [1514151725,
#   'Round 1 Bowling & Amusement',
#   33.99330201019182,
#   -117.92715306147082,
#   '91748',
#   'Industry',
#   'CA',
#   'United States',
#   'Bowling Alley'],
#  [1514094038,
#   'Sam Woo BBQ',
#   34.10432744116962,
#   -118.0865843822355,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1514087674,
#   'Hollywood Burbank Airport (BUR)',
#   34.19635394679802,
#   -118.35297703742982,
#   '91505',
#   'Burbank',
#   'CA',
#   'United States',
#   'Airport'],
#  [1514076587,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1513975941,
#   'San Francisco Soup Company',
#   37.79313424416357,
#   -122.40041919066859,
#   '94104',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Soup Place'],
#  [1513918812,
#   'Sababa',
#   37.791185,
#   -122.404219,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Mediterranean Restaurant'],
#  [1513744943,
#   'Golden Star Vietnamese Restaurant',
#   37.79452637823364,
#   -122.40560257441966,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1513657021,
#   'Pho Delicious',
#   37.79844822234438,
#   -122.40885061512955,
#   '94133',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1513456651,
#   'Boba Guys',
#   37.77290679880422,
#   -122.42350730562886,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1513113778,
#   'Homage',
#   37.790370627709336,
#   -122.40346670150758,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'New American Restaurant'],
#  [1512791861,
#   'Top of the Mark',
#   37.791552,
#   -122.410362,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Hotel Bar'],
#  [1512765680,
#   'Super Duper Burger',
#   37.7914365,
#   -122.4039689,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1512334120,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1512329934,
#   'Sharetea',
#   37.784581222868766,
#   -122.4031828312435,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1511989817,
#   'The Plant Cafe Organic',
#   37.79252480866014,
#   -122.39846488908981,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Café'],
#  [1511979431,
#   'Saint Francis Medical Group',
#   37.789276831325246,
#   -122.41755627397285,
#   '94109',
#   'San Francisco',
#   'CA',
#   'United States',
#   "Doctor's Office"],
#  [1511977067,
#   'SleepQuest - San Francisco Patient Service Center',
#   37.784025,
#   -122.432111,
#   '94115',
#   'San Francisco',
#   'CA',
#   'United States',
#   "Doctor's Office"],
#  [1511914728,
#   'SleepQuest - San Francisco Patient Service Center',
#   37.784025,
#   -122.432111,
#   '94115',
#   'San Francisco',
#   'CA',
#   'United States',
#   "Doctor's Office"],
#  [1511801015,
#   'SimonMed Imaging',
#   37.786691378507975,
#   -122.42095272709243,
#   '94109',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Medical Center'],
#  [1511794760,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1511788156,
#   'Los Angeles International Airport (LAX)',
#   33.94332434443264,
#   -118.405601978302,
#   '90045',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Airport'],
#  [1511739670,
#   'Young Dong Tofu',
#   34.103976245827795,
#   -118.08747287568985,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Korean Restaurant'],
#  [1511718848,
#   'AMC Santa Anita 16',
#   34.1353904958751,
#   -118.04887345491872,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1511669460,
#   "B-Man's Teriyaki & Burgers",
#   34.12759890401646,
#   -118.09110865952208,
#   '91107',
#   'Pasadena',
#   'CA',
#   'United States',
#   'American Restaurant'],
#  [1511655807,
#   'Vons',
#   34.125034,
#   -118.0577682,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Supermarket'],
#  [1511655793,
#   'AU 79 Tea House',
#   34.12418378964051,
#   -118.0581751120607,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Tea Room'],
#  [1511652163,
#   'Lacy Park',
#   34.12027014160729,
#   -118.12110012379726,
#   '91108',
#   'San Marino',
#   'CA',
#   'United States',
#   'Park'],
#  [1511562344,
#   'California Bank & Trust',
#   34.126800537109375,
#   -118.05455017089844,
#   '',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Bank'],
#  [1511558856,
#   'Full House Seafood Restaurant',
#   34.12488088781389,
#   -118.05929943656766,
#   '91007',
#   'Arcadia',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1511416919,
#   'Los Angeles International Airport (LAX)',
#   33.94332434443264,
#   -118.405601978302,
#   '90045',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Airport'],
#  [1511406658,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1511404272,
#   'Plentea',
#   37.79145178854404,
#   -122.4040515374968,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1511388875,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1511297335,
#   'Sapphire Asian Cuisine & Lounge',
#   37.794017429031854,
#   -122.40084361383826,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1511193115,
#   'SimonMed Imaging',
#   37.786691378507975,
#   -122.42095272709243,
#   '94109',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Medical Center'],
#  [1511140379,
#   'Whole Foods Market',
#   37.768735586838446,
#   -122.42693589670061,
#   '94114',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1511133408,
#   'Sennheiser',
#   37.788807,
#   -122.406575,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Music Store'],
#  [1511132185,
#   "Trader Joe's",
#   37.78554041959348,
#   -122.40545481697127,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Grocery Store'],
#  [1511131614,
#   'Cole Hardware',
#   37.784919,
#   -122.40478,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Hardware Store'],
#  [1511130620,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1511119859,
#   'Super Duper Burgers',
#   37.784815548410776,
#   -122.40353657596643,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1511043604,
#   "Angelica's Hair Salon",
#   37.757517,
#   -122.420957,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Cosmetics Shop'],
#  [1511040031,
#   'Taqueria Cancún',
#   37.76041434416447,
#   -122.41924383532758,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burrito Place'],
#  [1510956522,
#   'Onigilly',
#   37.791467040344536,
#   -122.40406312658435,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Japanese Restaurant'],
#  [1510734122,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1510727802,
#   'Los Angeles International Airport (LAX)',
#   33.94332434443264,
#   -118.405601978302,
#   '90045',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Airport'],
#  [1510712274,
#   'Golden Deli Vietnamese Restaurant',
#   34.102792400002144,
#   -118.1117266923932,
#   '91776',
#   'San Gabriel',
#   'CA',
#   'United States',
#   'Vietnamese Restaurant'],
#  [1510701047,
#   'UCLA Health Epilepsy & Brain Mapping Program',
#   34.134056,
#   -118.15083,
#   '91105',
#   'Pasadena',
#   'CA',
#   'United States',
#   "Doctor's Office"],
#  [1510687774,
#   'Sea Harbour Seafood Restaurant',
#   34.07984066331326,
#   -118.07333182757715,
#   '91770',
#   'Rosemead',
#   'CA',
#   'United States',
#   'Chinese Restaurant'],
#  [1510647428,
#   'Los Angeles International Airport (LAX)',
#   33.94332434443264,
#   -118.405601978302,
#   '90045',
#   'Los Angeles',
#   'CA',
#   'United States',
#   'Airport'],
#  [1510632040,
#   'San Francisco International Airport (SFO)',
#   37.6167130000997,
#   -122.38709449768066,
#   '94128',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Airport'],
#  [1510260514,
#   "McDonald's",
#   37.79389,
#   -122.399109,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Fast Food Restaurant'],
#  [1509984834,
#   'LabCorp',
#   37.788144974412674,
#   -122.40990094484356,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Medical Lab'],
#  [1509916562,
#   'Heart of The City Farmers Market',
#   37.77989039851448,
#   -122.41431623697281,
#   '94102',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Farmers Market'],
#  [1509911117,
#   'City View Restaurant',
#   37.794191,
#   -122.403918,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Dim Sum Restaurant'],
#  [1509827088,
#   'Oxygen Massage Therapy Mission',
#   37.75510272800073,
#   -122.4228797738143,
#   '94110',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Massage Studio'],
#  [1509753539,
#   'AMC Metreon 16',
#   37.784654053391435,
#   -122.40318899435513,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Movie Theater'],
#  [1509743552,
#   'Sharetea',
#   37.784581222868766,
#   -122.4031828312435,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Bubble Tea Shop'],
#  [1509739771,
#   'Circle Medical',
#   37.782118,
#   -122.408275,
#   '94103',
#   'San Francisco',
#   'CA',
#   'United States',
#   "Doctor's Office"],
#  [1509139214,
#   'Gott’s Roadside',
#   37.795793782401226,
#   -122.39424059385291,
#   '94111',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Burger Joint'],
#  [1509116985,
#   'Hilton',
#   37.7952284,
#   -122.4040729,
#   '94108',
#   'San Francisco',
#   'CA',
#   'United States',
#   'Hotel'],
#  ...]

# %%
# Convert to pandas dataframe
header = ['created_at', 'timezone_offset', 'venue', 'venue_lat', 'venue_lon', 'venue_postalcode', 'venue_city', 'venue_state', 'venue_country', 'venue_category']
df = pd.DataFrame(checkins, columns = header)

# %%
# Clean-up check-in created_at time
# Convert epoch time to datetime
df['created_at'] = pd.to_datetime(df['created_at'], unit='s')

# Function to adjust timezone to be consistently local time
def fix_timezone(row):
    return row['created_at'] + timedelta(minutes = row['timezone_offset'])

# Adjust timezones
df['created_at_adjusted'] = df.apply(fix_timezone, axis = 1)

# %%
# Fill in blank venue_city with Google Maps geocoding
# Need to set condition country by country, city data doesn't appear with in the same spot when calling reverse_geocode
def fix_cityname(row):
    reverse_geocode_result = gmaps.reverse_geocode((str(row['venue_lat']) + ', ' + str(row['venue_lon'])))
    if row['venue_city'] == '' or row['venue_city'] is None:
        if row['venue_country'] == 'United States':
            city = reverse_geocode_result[0]['address_components'][2]['long_name']
        if row['venue_country'] == 'South Korea':
            city = reverse_geocode_result[0]['address_components'][4]['long_name']
        if row['venue_country'] == 'France':
            city = reverse_geocode_result[0]['address_components'][2]['long_name']
        return city

    else:
        return row['venue_city']

# %%
df['venue_city'] = df.apply(fix_cityname, axis = 1)

# %%
# Parse out check-in times for hour and day of week for more granular charting
df['created_at_adjusted_hour'] = df['created_at_adjusted'].dt.hour
df['created_at_adjusted_weekday'] = df['created_at_adjusted'].dt.weekday

# %%
# Aggregate data by venue, city, and venue category for charting
df_venue = df.groupby(['venue']).count()['created_at'].sort_values(ascending=False)
df_city = df.groupby(['venue_city']).count()['created_at'].sort_values(ascending=False)
df_category = df.groupby(['venue_category']).count()['created_at'].sort_values(ascending=False)

# %%
# Create csv for Tableau dashboard
df.to_csv('swarm data.csv')
